# %% [markdown]
# # Data Structures and Algorithms
#
# **Todsapon Banklongsi (Aj. NesT the Series)**
#
# Facebook: [Aj. NesT the Series](https://www.facebook.com/ajnesttheseries)
#
# YouTube: [Aj. NesT the Series](https://www.youtube.com/ajnesttheseries)

# %% [markdown]
# # Tree vs Graph
#
# Trees are nothing more than restricted types of graphs, just with many more rules to follow . A tree will always be a graph, but not all graphs will be trees.
#
# ![alt text](https://techdifferences.com/wp-content/uploads/2018/03/Untitled-1.jpg)
#
# Source: Techdifferences
#
# ![alt text](https://pediaa.com/wp-content/uploads/2019/01/Difference-Between-Tree-and-Graph-Comparison-Summary.jpg)
#
# Source: Pediaa
#
# # Graph
#
# A graph is a data structure where a **Node** can have zero or more adjacent elements. The *connection between two nodes* is called **Edge**.*Nodes can also be called* **Vertices**.
#
# **Parts of a graph**
#
# 1. **Vertices** (Nodes) — Where data is stored.
#
# 2. **Edges** (Connections) — Connects 2 different vertices together. And they can also go in one direction. Which creates what’s called directed graphs or digraphs. Additionally, these edges can have weights.
#
# The **Degree** is the number of edges connected to a vertex. E.g., the **purple vertex** has a degree of **3** while the **blue** one has a degree of **1**.
#
# ![alt text](https://adrianmejia.com/images/graph-parts.jpg)
#
# Source: AdrianMejia
#
# It’s very important to learn the formal “language” to work with graphs:
#
# **|V| = Total number of vertices (nodes) in the graph.**
#
# **|E| = Total number of connections (edges) in the graph.**
#
# In the example below, |V| = 6 because there are six nodes (circles) and
# |E| = 7 because there are seven edges (lines).
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/5vbqwpnuO8nAdj51kN4Bk8ozdpL6WYWkkQHu)
#
# Source: freecodecamp
#
# **Types of Graphs**
#
# 1.**Undirected** — Vertices on both sides of the edges have connection to each other and you can see that the relationship goes both ways.
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/kgILL-2f3arDbAUOwFKLRFxp2khpvvZ5J9vF)
#
# Source: freecodecamp
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/ijCoLsVRLPWxVTmUI13tnv-aTOtyiHHonk11)
#
# Source: freecodecamp
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/Fe2wHkUPwhxYxdd9LXschmm2VfNaMhiiHJrb)
#
# Source: freecodecamp
#
# 2.**Directed** — Vertices on both sides of the edges have connection to each other. But the connection only goes one way(either from the first vertex to the second vertex, or otherwise).
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/9KWaj30YcJDBhvteJvkQQ7YvOu3PVaPBaXpw)
#
# Source: freecodecamp
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/U7ZcYL5X54m06sKCuQ3wv8K2-Ka7ixE67nxg)
#
# Source: freecodecamp
#
# ![alt text](https://cdn-media-1.freecodecamp.org/images/CPepyBE1XXy7fcXemQXQZGbncbZ4RCPH9Ezx)
#
# Source: freecodecamp
#
# Vertex can have edges that go to itself (e.g., blue node), this is called **self-loop**.
#
# ![alt text](https://adrianmejia.com/images/directed-vs-undirected-graph.jpg)
#
# Source: AdrianMejia
#
# A graph can have **Cycles** which means that if you traverse through the node, you could get the same node more than once. The graph without cycles is called **Acyclic** graph. Also, **Acyclic Undirected Graphs** are called **Tree**
#
# ![alt text](https://adrianmejia.com/images/cyclic-vs-acyclic-directed-graph.jpg)
#
# Source: AdrianMejia
#
# ![alt text](https://adrianmejia.com/images/connected-vs-complete-graph.jpg)
#
# Source: AdrianMejia

# %% [markdown]
# # Applications of Graph Data Structure
#
# When edges have values/cost assigned to them, we say we have a weighted graph. If the weight is absent, we can assume it’s 1.
#
# ##1) Airline Traffic
#
# Node/vertex = Airport
#
# Edges = direct flights between two airports
#
# Weight = miles between two airports
#
# ![alt text](https://adrianmejia.com/images/airports-weighted-graph.jpg)
#
# Source: AdrianMejia
#
# ##2) GPS Navigator -> Time, Distance, Cost
#
# Node = road intersection
#
# Edge = road
#
# Weight = time required to go from one intersection to another/ distance
#
# ![alt text](https://blog-c7ff.kxcdn.com/blog/wp-content/uploads/2017/01/West-central-park-road-1.png)
#
# Source: hackerearth
#
# ![alt text](http://blogs.cornell.edu/info2040/files/2011/09/econ2040_blog_graph1.png)
#
# Source: blogs.cornell.edu
#
# ![alt text](http://1.bp.blogspot.com/-GhhPoqeoWLI/TZd1J3-ON9I/AAAAAAAAAB4/Ii6_aHDkuFM/s1600/WeightedNetwork.jpg)
#
# Source: recursivediscursion
#
# ![alt text](https://adrianmejia.com/images/map-graph.jpg)
#
# Source: AdrianMejia
#
# ##3) Networks Routing
#
# Node = server
#
# Edge = data link
#
# Weight = connection speed
#
# ![alt text](https://s3.amazonaws.com/dev.assets.neo4j.com/wp-content/uploads/20171228165202/NetworkDiagram.png)
#
# Source: neo4j
#
# ##4) Facebook for Suggesting Friends
#
# ![alt text](https://cdn-images-1.medium.com/max/600/1*kiLOLZ6ERMeJ_wHmjgHitQ.png)
#
# Source: kdnuggets

# %% [markdown]
# # Graph Search
#
# ##Depth-First Search (DFS) - Graph search
#
# DFS is different algorithm in that it first starts with the starting node then selects a path and travels that path as far as it can before backtracking. I implemented this non-recursively using a **Stack**, keeping track of its visited neighbors.
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/7/7f/Depth-First-Search.gif)
#
# Source: AdrianMejia
#
# ![alt text](https://camo.githubusercontent.com/0200351e288c90c4a2ccc54534ba8b7c3e2b23f2/687474703a2f2f7265732e636c6f7564696e6172792e636f6d2f647172326d656a68632f696d6167652f75706c6f61642f76313530313336303733342f6466735f7630706935702e676966)
#
# Source: seanperfecto
#
# ##Breadth-First Search (BFS) - Graph search
#
# BFS is an algorithm that start at the starting node and explores its neighbors first, before moving on to their neighbors. My implementation is non-recursive, as it uses a **Queue** and checks whether the node has been visited or not.
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/5/5d/Breadth-First-Search-Algorithm.gif)
#
# Source: AdrianMejia
#
# ![alt text](https://camo.githubusercontent.com/2dbee6a8b24b0921898ffe2c0e1bd4a81a8f2f0f/687474703a2f2f7265732e636c6f7564696e6172792e636f6d2f647172326d656a68632f696d6167652f75706c6f61642f76313530313336303734362f6266735f7373776d657a2e676966)
#
# Source: seanperfecto
#
# ![alt text](https://raw.githubusercontent.com/andreaiacono/andreaiacono.github.io/master/img/graphlab/traverse.gif)
#
# Source: andreaiacono

# %% [markdown]
# ### Graph Exercises for Data Structures and Algorithms
#
# ### Graph Exercise 1: Basic Graph
# Creating Graph by Adding Vertexs and Edges
#
# Finding Path using Simple Path: A path with no repeated vertices is called a simple path.
#
# ![alt text](https://www.python-course.eu/images/simple_graph_with_loop.png)
#
# Source: python-course.eu

# %%
# Graph Exercise 1: Basic Graph
# Creating Graph by Adding Vertexs and Edges
# Finding Path using Simple Path: A path with no repeated vertices is called a simple path.
""" 
Reference: https://www.python-course.eu/graphs_python.php
"""

class Graph(object):

    def __init__(self, graph_dict=None):
        """ initializes a graph object 
            If no dictionary or None is given, 
            an empty dictionary will be used
        """
        if graph_dict == None:
            graph_dict = {}
        self.__graph_dict = graph_dict

    def vertices(self):
        """ returns the vertices of a graph """
        return list(self.__graph_dict.keys())

    def edges(self):
        """ returns the edges of a graph """
        return self.__generate_edges()

    def add_vertex(self, vertex):
        """ If the vertex "vertex" is not in 
            self.__graph_dict, a key "vertex" with an empty
            list as a value is added to the dictionary. 
            Otherwise nothing has to be done. 
        """
        if vertex not in self.__graph_dict:
            self.__graph_dict[vertex] = []

    def add_edge(self, edge):
        """ assumes that edge is of type set, tuple or list; 
            between two vertices can be multiple edges! 
        """
        edge = set(edge)
        (vertex1, vertex2) = tuple(edge)
        if vertex1 in self.__graph_dict:
            self.__graph_dict[vertex1].append(vertex2)
        else:
            self.__graph_dict[vertex1] = [vertex2]

    def __generate_edges(self):
        """ A static method generating the edges of the 
            graph "graph". Edges are represented as sets 
            with one (a loop back to the vertex) or two 
            vertices 
        """
        edges = []
        for vertex in self.__graph_dict:
            for neighbour in self.__graph_dict[vertex]:
                if {neighbour, vertex} not in edges:
                    edges.append({vertex, neighbour})
        return edges

    def __str__(self):
        res = "vertices: "
        for k in self.__graph_dict:
            res += str(k) + " "
        res += "\nedges: "
        for edge in self.__generate_edges():
            res += str(edge) + " "
        return res

    # Simple Path
    def find_path(self, start_vertex, end_vertex, path=None):
        """ find a path from start_vertex to end_vertex 
            in graph """
        if path == None:
            path = []
        graph = self.__graph_dict
        path = path + [start_vertex]
        if start_vertex == end_vertex:
            return path
        if start_vertex not in graph:
            return None
        for vertex in graph[start_vertex]:
            if vertex not in path:
                extended_path = self.find_path(vertex, 
                                               end_vertex, 
                                               path)
                if extended_path: 
                    return extended_path
        return None

    # All Simple Path
    def find_all_paths(self, start_vertex, end_vertex, path=[]):
        """ find all paths from start_vertex to 
            end_vertex in graph """
        graph = self.__graph_dict 
        path = path + [start_vertex]
        if start_vertex == end_vertex:
            return [path]
        if start_vertex not in graph:
            return []
        paths = []
        for vertex in graph[start_vertex]:
            if vertex not in path:
                extended_paths = self.find_all_paths(vertex, 
                                                     end_vertex, 
                                                     path)
                for p in extended_paths: 
                    paths.append(p)
        return paths

if __name__ == "__main__":

    g = { "a" : ["d"],
          "b" : ["c"],
          "c" : ["b", "c", "d", "e"],
          "d" : ["a", "c"],
          "e" : ["c"],
          "f" : []
        }

    graph = Graph(g)
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())

    print("\nAdd vertex:")
    graph.add_vertex("z")
    print("Vertices of graph:")
    print(graph.vertices())
    print("Adding an edge:")
    graph.add_edge({"a","z"})
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())

    print('\nAdding an edge:')
    graph.add_edge({"z","y"})
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())

    print('\nAdding an edge:')
    graph.add_edge({"d","y"})
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())   

    print('\nAdding an edge:')
    graph.add_edge({"d","e"})
    print("Vertices of graph:")
    print(graph.vertices())
    print("Edges of graph:")
    print(graph.edges())  
    
    print('\nSTART PATH FROM VERTEX')
    print('The path from vertex "a" to vertex "b":')
    path = graph.find_path("a", "b")
    print(path)

    print('\nThe path from vertex "a" to vertex "f":')
    path = graph.find_path("a", "f")
    print(path)

    print('\nThe path from vertex "c" to vertex "c":')
    path = graph.find_path("c", "c")
    print(path)

    print('\nThe path from vertex "y" to vertex "b":')
    path = graph.find_path("y", "b")
    print(path)

    print('\nThe path from vertex "a" to vertex "c":')
    path = graph.find_path("a", "c")
    print(path)

    print('\nThe path from vertex "z" to vertex "e":')
    path = graph.find_path("z", "e")
    print(path)

    print('\nAll paths from vertex "y" to vertex "b":')
    path = graph.find_all_paths("y", "b")
    print(path)

    print('\nAll paths from vertex "a" to vertex "c":')
    path = graph.find_all_paths("a", "c")
    print(path)

    print('\nAll paths from vertex "z" to vertex "e":')
    path = graph.find_all_paths("z", "e")
    print(path)
# Out:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f']
# Edges of graph:
# [{'d', 'a'}, {'b', 'c'}, {'c'}, {'d', 'c'}, {'e', 'c'}]
#
# Add vertex:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z']
# Adding an edge:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z']
# Edges of graph:
# [{'d', 'a'}, {'b', 'c'}, {'c'}, {'d', 'c'}, {'e', 'c'}, {'z', 'a'}]
#
# Adding an edge:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z', 'y']
# Edges of graph:
# [{'d', 'a'}, {'b', 'c'}, {'c'}, {'d', 'c'}, {'e', 'c'}, {'z', 'a'}, {'y', 'z'}]
#
# Adding an edge:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z', 'y']
# Edges of graph:
# [{'d', 'a'}, {'b', 'c'}, {'c'}, {'d', 'c'}, {'e', 'c'}, {'z', 'a'}, {'y', 'z'}, {'y', 'd'}]
#
# Adding an edge:
# Vertices of graph:
# ['a', 'b', 'c', 'd', 'e', 'f', 'z', 'y']
# Edges of graph:
# [{'d', 'a'}, {'b', 'c'}, {'c'}, {'d', 'c'}, {'e', 'c'}, {'d', 'e'}, {'z', 'a'}, {'y', 'z'}, {'y', 'd'}]
#
# START PATH FROM VERTEX
# ...

# %% [markdown]
# **Assignment of Graph Exercise 1: ให้วาดรูปกราฟที่ได้จากการรันผล และอธิบายการทำงานทุกส่วนของโปรแกรมให้ชัดเจนว่าทำไมถึงได้ผลลัพธ์แบบนี้**

# %% [markdown]
# ### Graph Exercise 2: Breadth-First Search (BFS) Traversal
#
# ![alt text](https://pythoninwonderland.files.wordpress.com/2017/03/graph1.png)
#
# Source: pythoninwonderland
#
# **BFS with Queue**
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/d/d3/Fifo_queue.png)
#
# Source: wikipedia

# %%
# Graph Exercise 2: Breadth-First Search (BFS) Traversal
"""
Reference: https://pythoninwonderland.wordpress.com/2017/03/18/how-to-implement-breadth-first-search-in-python/
"""
# sample graph implemented as a dictionary
graph = {'A': ['B', 'E', 'C'],
         'B': ['A','D', 'E'],
         'C': ['A', 'F', 'G'],
         'D': ['B'],
         'E': ['A', 'B','D'],
         'F': ['C'],
         'G': ['C']}

# visits all the nodes of a graph (connected component) using BFS
def bfs_traversal(graph, start):
    # keep track of all visited nodes
    explored = []
    # keep track of nodes to be checked
    queue = [start] 
    # keep looping until there are nodes still to be checked
    while queue:
        # pop shallowest node (first node) from queue
        node = queue.pop(0)
        if node not in explored:
            # add node to list of checked nodes
            explored.append(node)
            neighbours = graph[node]
            # add neighbours of node to queue
            for neighbour in neighbours:
                queue.append(neighbour)
    return explored
 
bfs_path = bfs_traversal(graph,'A') # returns ['A', 'B', 'E', 'C', 'D', 'F', 'G']
print(bfs_path)
# Out:
# ['A', 'B', 'E', 'C', 'D', 'F', 'G']

# %% [markdown]
# **Assignment of Graph Exercise 2: อธิบายการทำงานทุกส่วนของโปรแกรมให้ชัดเจนว่าทำไมถึงได้ผลลัพธ์แบบนี้**
#
# **Answer of Graph Exercise 2**
#
# ![alt text](https://pythoninwonderland.files.wordpress.com/2017/03/graphorder.png)

# %% [markdown]
# ### Graph Exercise 3: Depth-First Search (DFS) Traversal
#
# ![alt text](https://pythoninwonderland.files.wordpress.com/2017/03/graph1.png)
#
# Source: pythoninwonderland
#
# **DFS with Stack**
#
# ![alt text](https://upload.wikimedia.org/wikipedia/commons/b/b4/Lifo_stack.png)
#
# Source: wikipedia

# %%
# Graph Exercise 3: Depth-First Search (DFS) Traversal
"""
Reference: https://stackoverflow.com/questions/43430309/depth-first-search-dfs-code-in-python/43869149
"""
# sample graph implemented as a dictionary
graph = {'A': ['B', 'E', 'C'],
         'B': ['A','D', 'E'],
         'C': ['A', 'F', 'G'],
         'D': ['B'],
         'E': ['A', 'B','D'],
         'F': ['C'],
         'G': ['C']}

visited = []

def dfs_traversal(graph, node):
    visited = [node]
    stack = [node]
    while stack:
        node = stack[-1]
        if node not in visited:
            visited.extend(node)
        remove_from_stack = True
        for next in graph[node]:
            if next not in visited:
                stack.extend(next)
                remove_from_stack = False
                break
        if remove_from_stack:
            stack.pop()
    return visited

dfs_path = dfs_traversal(graph,'A')
print(dfs_path)
# Out:
# ['A', 'B', 'D', 'E', 'C', 'F', 'G']

# %% [markdown]
# **Assignment of Graph Exercise 3:**
# **อธิบายการทำงานทุกส่วนของโปรแกรมให้ชัดเจนว่าทำไมถึงได้ผลลัพธ์แบบนี้**
#
# **Answer of Graph Exercise 3**
